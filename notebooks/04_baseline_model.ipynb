# %% [markdown]
# # Post Pandemic Regime Shifts in Labor Market: Model Selection, Train/Test Split, and Baseline Models

# %% [markdown]
# ## Purpose

# %% [markdown]
# ## Research Context

# %% [markdown]
# ## Imports and Configuration
